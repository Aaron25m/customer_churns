# %%
# !pip install -q pycaret

# %%
# !pip install mlflow

# %%
# Import libraries
import pandas as pd
import numpy as np
from pycaret.classification import *

# Read CSV data
data = pd.read_csv('https://raw.githubusercontent.com/srees1988/predict-churn-py/main/customer_churn_data.csv')

# Replace blanks with np.nan
data['TotalCharges'] = data['TotalCharges'].replace(' ', np.nan).astype('float64')

# Check data types after the fix
print(data.dtypes)

# Initialize PyCaret setup
clf = setup(data=data, target='Churn', session_id=123)
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object
# <style type="text/css">
# #T_d2f63_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d2f63" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2f63_level0_col0" class="col_heading level0 col0" >Description</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_fe596 th {
#   text-align: left;
# }
# ...

# %%
print(best_model)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
save_model(best_model, 'my_first_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['SeniorCitizen', 'tenure',
#                                               'MonthlyCharges', 'TotalCharges'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty...
#                                      transformer=TargetEncoder(cols=['customerID'],
# ...

# %%
# load pipeline from file
my_pipeline = load_model('my_first_pipeline')
# sklearn settings to render diagram
from sklearn import set_config
set_config(display = 'diagram')
# display pipeline
print(my_pipeline)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['SeniorCitizen', 'tenure',
#                                              'MonthlyCharges', 'TotalCharges'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None...
#                                     transformer=TargetEncoder(cols=['customerID'],
#                                                               drop_invariant=False,
# ...

# %%
# !mlflow ui
# Out:
# [2024-11-08 16:32:54 +0000] [20537] [INFO] Starting gunicorn 23.0.0
# [2024-11-08 16:32:54 +0000] [20537] [INFO] Listening at: http://127.0.0.1:5000 (20537)
# [2024-11-08 16:32:54 +0000] [20537] [INFO] Using worker: sync
# [2024-11-08 16:32:54 +0000] [20538] [INFO] Booting worker with pid: 20538
# [2024-11-08 16:32:54 +0000] [20539] [INFO] Booting worker with pid: 20539
# [2024-11-08 16:32:54 +0000] [20540] [INFO] Booting worker with pid: 20540
# [2024-11-08 16:32:54 +0000] [20541] [INFO] Booting worker with pid: 20541
